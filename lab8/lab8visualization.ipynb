# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
childcare_dataframe = pd.read_csv('Childcare.csv')

childcare_dataframe
# Out:
#        _id  LOC_ID                                           LOC_NAME  \
# 0        1    1013              Lakeshore Community Child Care Centre
# 1        2    1014            Alternative Primary School Parent Group
# 2        3    1015     Cardinal Leger Child Care Centre (Scarborough)
# 3        4    1016  George Brown - Richmond Adelaide Childcare Centre
# 4        5    1017  Woodland Nursery School (Warden Woods Communit...
# ...    ...     ...                                                ...
# 1066  1067   14579                  Guidepost Montessori At The Annex
# 1067  1068   14580                         The Montessori Schoolhouse
# 1068  1069   14598                          CV Early Learning Academy
# 1069  1070   14600                                 Bloomsbury Academy
# 1070  1071   14601                               Le Jardin De Moliere
#
#                 AUSPICE            ADDRESS    PCODE  ward               PHONE  \
# ...

# %%
childcare_dataframe.head(10)
# Out:
#    _id  LOC_ID                                           LOC_NAME  \
# 0    1    1013              Lakeshore Community Child Care Centre
# 1    2    1014            Alternative Primary School Parent Group
# 2    3    1015     Cardinal Leger Child Care Centre (Scarborough)
# 3    4    1016  George Brown - Richmond Adelaide Childcare Centre
# 4    5    1017  Woodland Nursery School (Warden Woods Communit...
# 5    6    1021  Centennial College Progress Campus Child Care ...
# 6    7    1029                       Air-O-Down Child Care Centre
# 7    8    1031            Cedarbrae Day Nurseries (20 Greencrest)
# 8    9    1037                  Tiago Avenue Community Child Care
# 9   10    1041                    Ledbury Park Child Care Program
#
#              AUSPICE              ADDRESS    PCODE  ward                PHONE  \
# 0  Non Profit Agency       101 SEVENTH ST  M8V 3B5     3       (416) 394-7601
# 1  Non Profit Agency      1100 SPADINA RD  M5N 2M6     8       (416) 322-5385
# ...

# %%
childcare_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1071 entries, 0 to 1070
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   _id          1071 non-null   int64
#  1   LOC_ID       1071 non-null   int64
#  2   LOC_NAME     1071 non-null   object
#  3   AUSPICE      1071 non-null   object
#  4   ADDRESS      1071 non-null   object
#  5   PCODE        1071 non-null   object
#  6   ward         1071 non-null   int64
#  7   PHONE        1071 non-null   object
#  8   bldg_type    1071 non-null   object
#  9   BLDGNAME     721 non-null    object
#  10  IGSPACE      1071 non-null   int64
#  11  TGSPACE      1071 non-null   int64
#  12  PGSPACE      1071 non-null   int64
#  13  KGSPACE      1071 non-null   int64
#  14  SGSPACE      1071 non-null   int64
#  15  TOTSPACE     1071 non-null   int64
#  16  subsidy      1071 non-null   object
#  17  run_date     1071 non-null   object
# ...

# %%
childcare_dataframe["AUSPICE"].value_counts()
# Out:
# AUSPICE
# Non Profit Agency                705
# Commercial Agency                327
# Public (City Operated) Agency     39
# Name: count, dtype: int64

# %%
plt.grid(True)

plt.plot(childcare_dataframe["_id"], childcare_dataframe['TOTSPACE'])
plt.title("Child care Space")
plt.xlabel("Id")
plt.ylabel("Total Space")
plt.xticks(range(0, max(childcare_dataframe["_id"]) + 1, 100))  
plt.show()

# %%
childcare_auspice_color = {"Non Profit Agency": "red", 
                      "Commercial Agency": "green", 
                      "Public (City Operated) Agency":"blue"}

for auspice, auspice_color in childcare_auspice_color.items():
    auspice_dataframe = iris_dataframe[childcare_dataframe["AUSPICE"] == auspice]
    plt.scatter(auspice_dataframe["_id"], auspice_dataframe["bldg_type"], c = auspice_color, label=auspice)

plt.grid(True)
plt.title("Agency Types")
plt.xlabel("ID")
plt.ylabel("Building")
plt.legend()
plt.xticks(ticks=range(0, max(auspice_dataframe["_id"]) + 1, 50)) 

plt.show()

# %%
sns.histplot(data=childcare_dataframe, x="AUSPICE")
plt.title("Agencies Count Toronto")
plt.xlabel("Agency type")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(data=childcare_dataframe, x="_id", hue="AUSPICE", fill=True, common_norm=False, palette="crest", alpha=0.2)

plt.title("Kernel Density Plot of childcare centres by agency type")
plt.xlabel("Childcare centre ID")
plt.ylabel("Density")
plt.xticks(ticks=range(0, max(childcare_dataframe["_id"]) + 1, 100)) 
plt.show()
